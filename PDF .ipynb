# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacementdata.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\ragus\AppData\Local\Temp\ipykernel_12584\2590864738.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"])
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
#creat function for (dataset,startrange,endrange)
def cal_pdf_probability(dataset,startrange,endrange):
    #using 3 libraries mat for creating plots in Python
    #scipy for normal distribution 
    # seaborn for creating a plot to visually 
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    #as=asix,sns.displot-for distrubution plot,dataset,kde=kernel density,kde_kwe for plot color blue and green.
    ax = sns.distplot(dataset, kde=True, kde_kws={"color": "blue"}, color="green")
    #using lib pyplot.axvline=axisverticalline,(startrang-color=red,endrange-color=red)
    pyplot.axvline(startrange,color="red")
    pyplot.axvline(endrange,color="red")

    #now we apply calcuation for pdf
    #sample(pandas dataframe)=variable to dataset
    sample=dataset

    #variable=samole_mean and sample_std(sample.mean(),sample.std())
    sample_mean=sample.mean()
    sample_std=sample.std()
    print("mean%.3f,standard deviation%.3f"%(sample_mean,sample_std))

    #distribution using norm called scipy lib,mean and std for distribution 
    dist=norm(sample_mean,sample_std)
    
    #traditional way 
    
    #values=value for value in range(startrange,endrange)
    #probabilities=[dist.pdf(value) for value in value]
    probabilities = [40,50]
    for value in range(40, 50):
        probabilities.append(dist.pdf(value))
    #calculating the "sum" of probabilities
    prob = sum(probabilities)
    #print("the are betweent range({40},{50}):{90}".format(startrange,endrange,prob(mean=67,std=10))
    print("the are betweent range({},{}):{}".format(startrange,endrange,prob))
    return prob

# %%
#call the function to specifically"ssc_p","hhs_p" given the values 
cal_pdf_probability(dataset["ssc_p"],40,50)
#mean=67,std=10,range=90
# Out:
# mean67.303,standard deviation10.827
# the are betweent range(40,50):90.04489259448346
# C:\Users\ragus\AppData\Local\Temp\ipykernel_12584\3670551512.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset, kde=True, kde_kws={"color": "blue"}, color="green")
# C:\Users\ragus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 90.04489259448346
